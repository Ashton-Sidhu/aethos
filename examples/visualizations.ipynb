# %%
# %load_ext autoreload
# %autoreload 2

# %%
import aethos as py
import seaborn as sns
import plotly
# Out:
# /home/sidha62/.virtualenvs/aethos/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning:
#
# `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ...

# %%
data = sns.load_dataset("iris")

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df = py.Data(data, target_field='species', report_name='test')

# %%
df.replace_missing_mean()
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 0        setosa           5.4          3.4           1.5          0.4
# 1    versicolor           6.2          2.2           4.5          1.5
# 2    versicolor           6.7          3.1           4.7          1.5
# 3    versicolor           5.2          2.7           3.9          1.4
# 4    versicolor           6.1          2.8           4.7          1.2
# 5        setosa           5.0          3.4           1.6          0.4
# 6     virginica           6.3          2.8           5.1          1.5
# 7    versicolor           5.7          2.8           4.1          1.3
# 8        setosa           4.8          3.4           1.9          0.2
# 9    versicolor           5.5          2.3           4.0          1.3
# 10    virginica           6.2          2.8           4.8          1.8
# 11       setosa           5.0          3.5           1.6          0.6
# ...

# %% [markdown]
# Install npm dependencies for saving bokeh plots

# %%
# %%bash
# npm install -g phantomjs-prebuilt
# Out:
# /usr/local/lib
# └─┬ phantomjs-prebuilt@2.1.16
#   ├── es6-promise@4.2.8
#   ├─┬ extract-zip@1.6.7
#   │ ├─┬ concat-stream@1.6.2
#   │ │ ├── buffer-from@1.1.1
#   │ │ ├── inherits@2.0.4
#   │ │ ├─┬ readable-stream@2.3.6
#   │ │ │ ├── core-util-is@1.0.2
#   │ │ │ ├── isarray@1.0.0
#   │ │ │ ├── process-nextick-args@2.0.1
#   │ │ │ ├── string_decoder@1.1.1
#   │ │ │ └── util-deprecate@1.0.2
#   │ │ └── typedarray@0.0.6
#   │ ├─┬ debug@2.6.9
#   │ │ └── ms@2.0.0
#   │ ├─┬ mkdirp@0.5.1
#   │ │ └── minimist@0.0.8
#   │ └─┬ yauzl@2.4.1
#   │   └─┬ fd-slicer@1.0.1
#   │     └── pend@1.2.0
#   ├─┬ fs-extra@1.0.0
#   │ ├── graceful-fs@4.2.3
#   │ ├── jsonfile@2.4.0
#   │ └── klaw@1.3.1
#   ├─┬ hasha@2.2.0
#   │ ├── is-stream@1.1.0
#   │ └─┬ pinkie-promise@2.0.1
#   │   └── pinkie@2.0.4
#   ├── kew@0.7.0
#   ├── progress@1.1.8
#   ├─┬ request@2.88.0
#   │ ├── aws-sign2@0.7.0
#   │ ├── aws4@1.9.0
#   │ ├── caseless@0.12.0
#   │ ├─┬ combined-stream@1.0.8
#   │ │ └── delayed-stream@1.0.0
# ...

# %%
df.barplot(x='species', y=['petal_width', 'sepal_width'], method='mean', stacked=True, output_file='bar.png')
# Out:
# /home/sidha62/.virtualenvs/aethos/lib/python3.6/site-packages/bokeh/util/deprecation.py:68: BokehDeprecationWarning:
#
# 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
#   <div class="bk-root" id="4d9da465-9099-4dc1-b3b0-70f1aa08be46" data-root-id="1266"></div>

# %%
df.raincloud(x='petal_width', output_file='rainforest.png')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# %%bash
# npm install -g electron@1.8.4 orca
# Out:
# /usr/local/lib
# ├─┬ electron@1.8.4
# │ ├── @types/node@8.10.59
# │ ├─┬ electron-download@3.3.0
# │ │ ├─┬ debug@2.6.9
# │ │ │ └── ms@2.0.0
# │ │ ├─┬ fs-extra@0.30.0
# │ │ │ ├── graceful-fs@4.2.3
# │ │ │ ├── jsonfile@2.4.0
# │ │ │ ├── klaw@1.3.1
# │ │ │ ├── path-is-absolute@1.0.1
# │ │ │ └─┬ rimraf@2.7.1
# │ │ │   └─┬ glob@7.1.6
# │ │ │     ├── fs.realpath@1.0.0
# │ │ │     ├─┬ inflight@1.0.6
# │ │ │     │ └── wrappy@1.0.2
# │ │ │     ├─┬ minimatch@3.0.4
# │ │ │     │ └─┬ brace-expansion@1.1.11
# │ │ │     │   ├── balanced-match@1.0.0
# │ │ │     │   └── concat-map@0.0.1
# │ │ │     └── once@1.4.0
# │ │ ├── home-path@1.0.7
# │ │ ├── minimist@1.2.0
# │ │ ├─┬ nugget@2.0.1
# │ │ │ ├─┬ pretty-bytes@1.0.4
# │ │ │ │ ├── get-stdin@4.0.1
# │ │ │ │ └─┬ meow@3.7.0
# │ │ │ │   ├─┬ camelcase-keys@2.1.0
# │ │ │ │   │ └── camelcase@2.1.1
# │ │ │ │   ├── decamelize@1.2.0
# │ │ │ │   ├─┬ loud-rejection@1.6.0
# │ │ │ │   │ ├─┬ currently-unhandled@0.4.1
# │ │ │ │   │ │ └── array-find-index@1.0.2
# ...

# %%
df.scatterplot(x='sepal_width', y='petal_width', z='petal_width', output_file='3d.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f59a963b0080> in <module>
# ----> 1 df.scatterplot(x='sepal_width', y='petal_width', z='petal_width', output_file='3d.png')
#
# ~/py-automl/aethos/visualizations/visualizations.py in scatterplot(self, x, y, z, category, title, size, output_file, **scatterplot_kwargs)
#     280             size=size,
#     281             output_file=output_file,
# --> 282             **scatterplot_kwargs,
#     283         )
#     284
#
# ~/py-automl/aethos/visualizations/visualize.py in scatterplot(x, y, z, data, category, title, size, output_file, **scatterplot_kwargs)
#     189
#     190         if output_file:  # pragma: no cover
# --> 191             fig.write_image(os.path.join(IMAGE_DIR, output_file))
#     192
#     193         fig.show()
#
# ...

# %%
df.scatterplot(x='sepal_width', y='petal_width', output_file='2d.png')
# Out:
# /home/sidha62/.virtualenvs/aethos/lib/python3.6/site-packages/bokeh/util/deprecation.py:68: BokehDeprecationWarning:
#
# 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
#   <div class="bk-root" id="ebae54cb-d05e-4a57-9428-71be2b62c0f3" data-root-id="1462"></div>

# %%
df.lineplot(x='sepal_width', y=['petal_width'], output_file='line.png')
# Out:
#   <div class="bk-root" id="03187b48-e171-4562-a201-9adf1a080a64" data-root-id="1685"></div>

# %%
df.correlation_matrix(output_file='corr.png')
# Out:
# <string>:6: DeprecationWarning:
#
# object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
df.pairplot(output_file='pair.png')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
df.jointplot(x='sepal_width', y='petal_width', output_file='joint.png')

# %%
df.histogram('sepal_length', 'sepal_width', output_file='hist.png')

# %%
df = py.Model(df)
